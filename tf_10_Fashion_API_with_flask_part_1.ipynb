# %%
# !pip install tensorflow==2.0.0

# %%
# putting a trained model into production using tensorflow 2.0 (tf serving) and flask framework.
from tensorflow.keras.datasets import fashion_mnist
import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# TRAIN THE MODEL

# %%
(X_train, y_train),(X_test, y_test) = fashion_mnist.load_data()
X_train = X_train/255.0
X_test = X_test/255.0
X_train = X_train.reshape(-1,28*28)
X_test = X_test.reshape(-1, 28*28)
X_train.shape, X_test.shape
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# ((60000, 784), (10000, 784))

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=128, activation='relu',input_shape=(784,)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.5355 - sparse_categorical_accuracy: 0.8102
# Epoch 2/5
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.3993 - sparse_categorical_accuracy: 0.8553
# Epoch 3/5
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3677 - sparse_categorical_accuracy: 0.8655
# Epoch 4/5
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.3466 - sparse_categorical_accuracy: 0.8734
# Epoch 5/5
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.3288 - sparse_categorical_accuracy: 0.8799

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
test_loss, test_accuracy
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
# save the architecture/topology of the network
model_json = model.to_json()
with open("drive/My Drive/fashion_model_flask.json", "w") as json_file:
    json_file.write(model_json)

# %%
# save the network weights
model.save_weights("drive/My Drive/fashion_model_flask.h5")
